# %% [markdown]
# # 📦 Notebook 1 — Connection & Setup Test
# Run these cells top to bottom to verify everything is working.

# %%
# Cell 1 — Add project root to path
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
from src.db import run_query, test_connection, get_schema

print('✅ Imports OK')
# Out:
# ✅ Imports OK

# %%
# Cell 2 — Test DB connection
ok = test_connection()
print('✅ Database connected!' if ok else '❌ Connection FAILED — check Docker is running')
# Out:
# ✅ Database connected!

# %%
# Cell 3 — Verify sample data
run_query("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public' ORDER BY 1")
# Out:
#    table_name
# 0    bookings
# 1  properties
# 2     reviews
# 3       users

# %%
# Cell 4 — Preview each table
for table in ['users', 'properties', 'bookings', 'reviews']:
    print(f'\n── {table.upper()} ──')
    display(run_query(f'SELECT * FROM {table} LIMIT 3'))
# Out:
# ── USERS ──
#    user_id    name              email  country signup_date
# 0        1  User 1  user1@example.com  Germany  2022-09-29
# 1        2  User 2  user2@example.com   Canada  2023-04-10
# 2        3  User 3  user3@example.com  Germany  2022-04-25
# ── PROPERTIES ──
#    property_id          name         city country   category  price_per_night  \
# 0            1      Condo #1  Los Angeles     USA      Cabin           244.73
# 1            2  Apartment #2       Austin     USA  Apartment            85.49
# 2            3      Condo #3      Chicago     USA      Cabin           367.88
#
#    host_id
# 0        8
# 1       12
# 2       12
# ── BOOKINGS ──
#    booking_id  property_id  user_id checkin_date checkout_date   amount  \
# 0           1            4       19   2023-06-24    2023-06-29  1031.76
# 1           2           14       98   2023-07-31    2023-08-05  2164.07
# 2           3           29       38   2023-05-14    2023-05-20  4177.10
#
#       status created_at
# 0  confirmed 2023-05-23
# 1  cancelled 2023-06-16
# 2  completed 2023-04-11
# ── REVIEWS ──
#    review_id  booking_id  rating             comment created_at
# 0          1         157       4  Average experience 2023-08-11
# 1          2         115       4           Not great 2023-09-23
# 2          3         258       2           Not great 2023-09-28

# %%
# Cell 5 — Row counts
run_query("""
    SELECT 'users'      AS table_name, COUNT(*) AS rows FROM users
    UNION ALL
    SELECT 'properties', COUNT(*) FROM properties
    UNION ALL
    SELECT 'bookings',   COUNT(*) FROM bookings
    UNION ALL
    SELECT 'reviews',    COUNT(*) FROM reviews
""")
# Out:
#    table_name  rows
# 0       users   100
# 1  properties    50
# 2    bookings   500
# 3     reviews   300

# %%
# Cell 6 — Auto-generated schema (used by LLM)
schema = get_schema()
print(schema)
# Out:
# Database Schema:
#
# public.bookings (
#   booking_id integer,
#   property_id integer,
#   user_id integer,
#   checkin_date date,
#   checkout_date date,
#   amount numeric,
#   status character varying,
#   created_at timestamp without time zone,
# )
#
# public.properties (
#   property_id integer,
#   name character varying,
#   city character varying,
#   country character varying,
#   category character varying,
#   price_per_night numeric,
#   host_id integer,
# )
#
# public.reviews (
#   review_id integer,
#   booking_id integer,
#   rating integer,
#   comment text,
#   created_at timestamp without time zone,
# )
#
# public.users (
#   user_id integer,
#   name character varying,
#   email character varying,
#   country character varying,
#   signup_date date,
# )

# %%
# Cell 7 — Test Ollama is running
import ollama
client = ollama.Client(host='http://localhost:11434')
resp = client.chat(
    model='llama3.2',
    messages=[{'role': 'user', 'content': 'Say: Ollama is working'}]
)
print(resp['message']['content'])
# Out:
# It seems like you're trying to simulate a message from the iconic Pokémon game. The correct phrase would be "Ollama, is it working?"
